# %%
import pyfolio as pf
import pandas as pd

# %%
returns = pd.read_csv("./backtesting_results/returns.csv", index_col=0, parse_dates=True)
positions = pd.read_csv("./backtesting_results/positions.csv", index_col=0, parse_dates=True)
transactions = pd.read_csv("./backtesting_results/transactions.csv", index_col=0, parse_dates=True)

# %%
transactions
# Out:
#                            amount    price  sid symbol         value
# date
# 2024-01-04 00:00:00+00:00   12331  96300.0    0    FPT -1.187475e+09
# 2024-01-04 00:00:00+00:00   42715  27800.0    1    HPG -1.187477e+09
# 2024-01-04 00:00:00+00:00   62172  19150.0    8    VPB -1.190594e+09
# 2024-01-04 00:00:00+00:00   51075  23250.0    9    VRE -1.187494e+09
# 2024-01-08 00:00:00+00:00     -85  97400.0    0    FPT  8.279000e+06
# ...                           ...      ...  ...    ...           ...
# 2024-03-01 00:00:00+00:00  -15105  70400.0    3    MSN  1.063392e+09
# 2024-03-01 00:00:00+00:00  -22819  46550.0    4    MWG  1.062224e+09
# 2024-03-01 00:00:00+00:00   21822  31750.0    5    STB -6.928485e+08
# 2024-03-01 00:00:00+00:00   16903  43700.0    7    VHM -7.386611e+08
# 2024-03-01 00:00:00+00:00   34476  19900.0    8    VPB -6.860724e+08
#
# [84 rows x 5 columns]

# %%
pf.create_returns_tear_sheet(returns['return'], positions, transactions)
# Out:
# c:\Users\tuan.dm\AppData\Local\Programs\Python\Python310\lib\site-packages\pyfolio\timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2023-11-21</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2024-03-04</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>3</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>40.5%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>9.8%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>12.9%</td>
#     </tr>
#     <tr>
# ...
